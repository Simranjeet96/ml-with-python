# %% [markdown]
# # PANDAS Module

# %% [markdown]
# ### IRIS Data Set

# %%
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\simra\\ML\\Lectures\\Lectures\\Lecture2-Pandas,Matplotlib'

# %%
import pandas as pd

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# ...

# %%
#return the type of iris dataset
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
#returns top 5 rows of the data set
iris.head()
#returns specified no of rows from top
iris.head(10)

#returns last 5 rows of the data set
iris.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
#returns header of each colums
iris.columns

#changes the header
iris.columns = ['sl','sw','pl','pw','flower_class']

iris.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_class'], dtype='object')

# %%
#returns a tuple (no of rows , no of columns)
iris.shape
# Out:
# (149, 5)

# %%
#returns type of each colums
iris.dtypes
# Out:
# sl              float64
# sw              float64
# pl              float64
# pw              float64
# flower_class     object
# dtype: object

# %%
#returns sum,mean etc calculated on each column
iris.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#returns a dataframe true if value is null else false
pd.isnull(iris)

#returns the number of null values in each column
pd.isnull(iris).sum()
# Out:
# sl              0
# sw              0
# pl              0
# pw              0
# flower_class    0
# dtype: int64

# %%
#returns a specified column
iris.sl


#returns specified rows and columns
iris.iloc[1:3 , 1:3]

#to print 0th row
iris.iloc[0:1]
# Out:
#     sl   sw   pl   pw flower_class
# 0  4.9  3.0  1.4  0.2  Iris-setosa

# %%
#to change the value to null
iris.iloc[1:3,1:3] = np.nan
iris.head()

iris.isnull()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-62-01055ace137b> in <module>()
#       1 #to change the value to null
# ----> 2 iris.iloc[1:3,1:3] = np.nan
#       3 iris.head()
#       4
#       5 iris.isnull()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     176         else:
#     177             key = com._apply_if_callable(key, self.obj)
# --> 178         indexer = self._get_setitem_indexer(key)
#     179         self._setitem_with_indexer(indexer, value)
#     180
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     163
#     164         try:
# --> 165             return self._convert_to_indexer(key, is_setter=True)
#     166         except TypeError as e:
#     167
#
# ...

# %%
#changes Nan value in specified column
iris.sw.fillna(1,inplace = True)
iris.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-bb0885656932> in <module>()
#       1 #changes Nan value in specified column
# ----> 2 iris.sw.fillna(1,inplace = True)
#       3 iris.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sw'

# %%
iris.pl.fillna(0,inplace = True)
iris.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-6344d3af1b54> in <module>()
# ----> 1 iris.pl.fillna(0,inplace = True)
#       2 iris.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pl'

# %%
iris.iloc[0:1] = np.nan
iris.head()
# Out:
# 0    NaN
# 1    0.0
# 2    0.0
# 3    1.4
# 4    1.7
# Name: pl, dtype: float64

# %%
#drop the rows with Nan in it
iris.dropna(inplace = True)

# %%
#to reset the index
iris.reset_index(drop = Ture , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-f0d7be698d61> in <module>()
#       1 #to reset the index
# ----> 2 iris.reset_index(drop = Ture , inplace = True)
#
# NameError: name 'Ture' is not defined
